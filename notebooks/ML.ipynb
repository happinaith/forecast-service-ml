# %%
import os
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow import keras
from datetime import datetime

# Обучение модели TensorFlow для прогнозирования курса рубля (USD/RUB)
# Если не установлены зависимости
# !pip install yfinance tensorflow pandas scikit-learn matplotlib

import matplotlib.pyplot as plt

# reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# --- Параметры ---
TICKER = "USDRUB=X"            # тикер USD/RUB на Yahoo Finance
START = "2015-01-01"
END = datetime.today().strftime("%Y-%m-%d")
WINDOW = 60                    # окно в днях для последовательностей
TEST_RATIO = 0.2
BATCH_SIZE = 32
EPOCHS = 50
MODEL_PATH = "rub_model.h5"
SCALER_PATH = "scaler.npy"     # сохраняем параметры scaler

# --- Загрузка данных ---
df = yf.download(TICKER, start=START, end=END, progress=False)
if df.empty:
    raise RuntimeError("Не удалось загрузить данные. Проверьте подключение или тикер.")
# используем колонку Close
series = df["Close"].ffill().dropna()

# --- Подготовка данных: нормализация и создание последовательностей ---
scaler = MinMaxScaler(feature_range=(0, 1))
prices = series.values.reshape(-1, 1)
prices_scaled = scaler.fit_transform(prices)

def create_sequences(data, window):
    X, y = [], []
    for i in range(len(data) - window):
        X.append(data[i:i+window])
        y.append(data[i+window])
    return np.array(X), np.array(y)

X, y = create_sequences(prices_scaled, WINDOW)
# разбиваем на train/test по хронологии
split_idx = int(len(X) * (1 - TEST_RATIO))
X_train, X_test = X[:split_idx], X[split_idx:]
y_train, y_test = y[:split_idx], y[split_idx:]

# убедимся в форме для LSTM: (samples, timesteps, features)
print("Shapes:", X_train.shape, y_train.shape, X_test.shape, y_test.shape)

# --- Модель ---
model = keras.Sequential([
    keras.layers.Input(shape=(WINDOW, 1)),
    keras.layers.LSTM(64, return_sequences=True),
    keras.layers.Dropout(0.2),
    keras.layers.LSTM(32),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1)
])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-3), loss="mse")
model.summary()

# --- Обучение ---
callbacks = [
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=8, restore_best_weights=True),
    keras.callbacks.ModelCheckpoint(MODEL_PATH, save_best_only=True, monitor="val_loss")
]

history = model.fit(
    X_train, y_train,
    validation_split=0.1,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks,
    verbose=1
)

# --- Оценка и прогноз ---
# прогноз на тестовой выборке
pred_scaled = model.predict(X_test)
pred = scaler.inverse_transform(pred_scaled)
y_true = scaler.inverse_transform(y_test)

# метрики (MAE, RMSE)
mae = np.mean(np.abs(pred.flatten() - y_true.flatten()))
rmse = np.sqrt(np.mean((pred.flatten() - y_true.flatten())**2))
print(f"Test MAE: {mae:.4f}, RMSE: {rmse:.4f}")

# визуализация: последние N точек
plt.figure(figsize=(12,5))
idxs = np.arange(len(y_true))
plt.plot(idxs, y_true, label="Actual")
plt.plot(idxs, pred, label="Predicted")
plt.title("USD/RUB — фактические vs прогноз")
plt.xlabel("Тимesteps (test set)")
plt.ylabel("Курс")
plt.legend()
plt.show()

# --- Сохранение scaler ---
np.save(SCALER_PATH, np.array([scaler.min_, scaler.scale_], dtype=object))
print(f"Модель сохранена в {MODEL_PATH}, scaler в {SCALER_PATH}")

# Пример прогнозирования одного шага вперед от последнего доступного окна
last_window = prices_scaled[-WINDOW:].reshape(1, WINDOW, 1)
next_scaled = model.predict(last_window)
next_pred = scaler.inverse_transform(next_scaled.reshape(-1,1))[0,0]
print(f"Прогноз курса на следующий торговый день: {next_pred:.4f} RUB")
# Out:
# Shapes: (2199, 60, 1) (2199, 1) (550, 60, 1) (550, 1)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 60, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...
